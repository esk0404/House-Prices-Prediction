# %% [markdown]
# # Getting Started

# %%
# !pip install pycaret
# Out:
# Collecting pycaret
#   Downloading pycaret-3.0.4-py3-none-any.whl (484 kB)
#      |████████████████████████████████| 484 kB 6.5 MB/s eta 0:00:01
# Collecting xxhash
#   Downloading xxhash-3.4.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      |████████████████████████████████| 194 kB 75.6 MB/s eta 0:00:01
# Collecting importlib-metadata>=4.12.0
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: lightgbm>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from pycaret) (3.2.0)
# Collecting ipywidgets>=7.6.5
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 87.4 MB/s eta 0:00:01
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting scikit-learn<1.3.0,>=1.0
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 63.1 MB/s eta 0:00:01
# Collecting yellowbrick>=1.4
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      |████████████████████████████████| 282 kB 75.0 MB/s eta 0:00:01
# Collecting tqdm>=4.62.0
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.7 MB/s  eta 0:00:01
# Collecting requests>=2.27.1
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s  eta 0:00:01
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 9.5 MB/s  eta 0:00:01
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1
#   Downloading sktime-0.19.2-py3-none-any.whl (17.0 MB)
#      |████████████████████████████████| 17.0 MB 64.9 MB/s eta 0:00:01
# Collecting imbalanced-learn>=0.8.1
#   Downloading imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
#      |████████████████████████████████| 257 kB 69.5 MB/s eta 0:00:01
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      |████████████████████████████████| 79.9 MB 71.4 MB/s eta 0:00:01
# Collecting schemdraw==0.15
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 49.2 MB/s eta 0:00:01
# Collecting pandas<2.0.0,>=1.3.0
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 74.4 MB/s eta 0:00:01    |█▊                              | 624 kB 74.4 MB/s eta 0:00:01
# Collecting pyod>=1.0.8
#   Downloading pyod-1.1.2.tar.gz (160 kB)
#      |████████████████████████████████| 160 kB 56.2 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.5.0 in /opt/conda/lib/python3.7/site-packages (from pycaret) (7.22.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.7/site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.7/site-packages (from pycaret) (5.1.2)
# Collecting plotly>=5.0.0
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      |████████████████████████████████| 15.6 MB 30.1 MB/s eta 0:00:01
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 84.3 MB/s eta 0:00:01
# Collecting numba>=0.55.0
#   Downloading numba-0.56.4-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 64.5 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.7/site-packages (from pycaret) (1.6.0)
# Collecting psutil>=5.9.0
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      |████████████████████████████████| 288 kB 66.6 MB/s eta 0:00:01
# Collecting tbats>=1.1.3
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 1.7 MB/s  eta 0:00:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 70.7 MB/s eta 0:00:01
# Requirement already satisfied: jinja2>=1.2 in /opt/conda/lib/python3.7/site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: scipy<2.0.0 in /opt/conda/lib/python3.7/site-packages (from pycaret) (1.5.4)
# Collecting deprecation>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting plotly-resampler>=0.8.3.1
#   Downloading plotly_resampler-0.9.2-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 7.9 MB/s  eta 0:00:01
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/lib/python3.7/site-packages (from pycaret) (0.12.2)
# Collecting numpy<1.24,>=1.21
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 68.7 MB/s eta 0:00:01
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 60.0 MB/s eta 0:00:01
# Collecting markupsafe>=2.0.1
#   Downloading MarkupSafe-2.1.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from schemdraw==0.15->pycaret) (3.7.4.3)
# Collecting importlib-resources
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.7/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from deprecation>=2.1.0->pycaret) (20.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.4.1)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (0.18.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (3.0.18)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (49.6.0.post20210108)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.5.0->pycaret) (5.0.5)
# Collecting comm>=0.1.3
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting widgetsnbextension~=4.0.9
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 55.0 MB/s eta 0:00:01
# Collecting jupyterlab-widgets~=3.0.9
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#      |████████████████████████████████| 214 kB 76.8 MB/s eta 0:00:01
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from lightgbm>=3.0.0->pycaret) (0.36.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->pycaret) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->pycaret) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->pycaret) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.0->pycaret) (7.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=3.3.0->pycaret) (1.15.0)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->pycaret) (4.7.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->pycaret) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->pycaret) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->pycaret) (20.3.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 67.8 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly>=5.0.0->pycaret) (7.0.0)
# Collecting tsdownsample==0.1.2
#   Downloading tsdownsample-0.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 65.2 MB/s eta 0:00:01
# Collecting dash>=2.9.0
#   Downloading dash-2.14.2-py3-none-any.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 31.1 MB/s eta 0:00:01
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.9.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      |████████████████████████████████| 138 kB 58.7 MB/s eta 0:00:01
# Requirement already satisfied: Werkzeug<3.1 in /opt/conda/lib/python3.7/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.0.1)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.7/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.3)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/lib/python3.7/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Collecting ansi2html
#   Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.7/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.3)
# Requirement already satisfied: click>=5.1 in /opt/conda/lib/python3.7/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/conda/lib/python3.7/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.7/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.23)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.7/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.4)
# Collecting statsmodels>=0.12.1
#   Downloading statsmodels-0.13.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 88.9 MB/s eta 0:00:01
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.27.1->pycaret) (2020.12.5)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      |████████████████████████████████| 136 kB 80.9 MB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.27.1->pycaret) (2.10)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting scikit-base<0.5.0
#   Downloading scikit_base-0.4.6-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 61.6 MB/s eta 0:00:01
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.7/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.12.1)
# Collecting packaging
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.1 MB/s  eta 0:00:01
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 34.2 MB/s eta 0:00:01
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.1.2-py3-none-any.whl size=190302 sha256=cba50493b246177de68d7a419cf291f239f593ce2521b0beacbac5450a225c3b
#   Stored in directory: /root/.cache/pip/wheels/81/5c/17/b1eae4439641e9c8661bfd4fb7b0322a18bcd73a56f7f83544
# Successfully built pyod
# Installing collected packages: typing-extensions, numpy, markupsafe, patsy, pandas, packaging, joblib, importlib-metadata, charset-normalizer, statsmodels, scikit-learn, requests, plotly, llvmlite, dash-table, dash-html-components, dash-core-components, ansi2html, widgetsnbextension, tsdownsample, scikit-base, pmdarima, orjson, numba, jupyterlab-widgets, importlib-resources, deprecated, dash, comm, yellowbrick, xxhash, wurlitzer, tqdm, tbats, sktime, schemdraw, pyod, psutil, plotly-resampler, pickle5, kaleido, ipywidgets, imbalanced-learn, deprecation, category-encoders, pycaret
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: patsy
#     Found existing installation: patsy 0.5.1
#     Uninstalling patsy-0.5.1:
#       Successfully uninstalled patsy-0.5.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.3
#     Uninstalling pandas-1.2.3:
#       Successfully uninstalled pandas-1.2.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.14.3
#     Uninstalling plotly-4.14.3:
#       Successfully uninstalled plotly-4.14.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.36.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns', None)
pd.set_option('max_rows', 90)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.neighbors import KNeighborsRegressor
import scipy.stats
from sklearn.preprocessing import StandardScaler
from pycaret.regression import setup, compare_models
from sklearn.model_selection import KFold, cross_val_score

from catboost import CatBoostRegressor
from sklearn.linear_model import BayesianRidge, HuberRegressor, Ridge, OrthogonalMatchingPursuit
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

import optuna
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-828511d8300c> in <module>
#      11 import scipy.stats
#      12 from sklearn.preprocessing import StandardScaler
# ---> 13 from pycaret.regression import setup, compare_models
#      14 from sklearn.model_selection import KFold, cross_val_score
#      15
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
train0 = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
test0 = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')
sample_submission = pd.read_csv('../input/house-prices-advanced-regression-techniques/sample_submission.csv')

# %%
train0

# %%
test0

# %%
sample_submission

# %% [markdown]
# # Combine Train and Test Sets

# %%
target = train0['SalePrice']
test_ids = test0['Id']

train1 = train0.drop(['Id', 'SalePrice'], axis=1)
test1 = test0.drop('Id', axis=1)

data1 = pd.concat([train1, test1], axis=0).reset_index(drop=True)
data1

# %%
target

# %% [markdown]
# # Cleaning

# %%
data2 = data1.copy()

# %% [markdown]
# ## Ensure Proper Data Types

# %%
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# ## Fill Categorical Missing Values

# %%
# Impute using a constant value
for column in [
    'Alley',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'FireplaceQu',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PoolQC',
    'Fence',
    'MiscFeature'
]:
    data2[column] = data2[column].fillna("None")

# Impute using the column mode
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    data2[column] = data2[column].fillna(data2[column].mode()[0])

# %%
data3 = data2.copy()

# %% [markdown]
# ## Numeric Missing Values

# %%
def knn_impute(df, na_target):
    df = df.copy()
    
    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[: ,numeric_df.isna().sum() == 0].columns
    
    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    
    df.loc[df[na_target].isna() == True, na_target] = y_pred
    
    return df

# %%
for column in [
    'LotFrontage',
    'MasVnrArea',
    'BsmtFinSF1',
    'BsmtFinSF2',
    'BsmtUnfSF',
    'TotalBsmtSF',
    'BsmtFullBath',
    'BsmtHalfBath',
    'GarageYrBlt',
    'GarageCars',
    'GarageArea'
]:
    data3 = knn_impute(data3, column)

# %%
data4 = data3.copy()

# %% [markdown]
# # Feature Engineering

# %%
data4["SqFtPerRoom"] = data4["GrLivArea"] / (data4["TotRmsAbvGrd"] +
                                                       data4["FullBath"] +
                                                       data4["HalfBath"] +
                                                       data4["KitchenAbvGr"])

data4['Total_Home_Quality'] = data4['OverallQual'] + data4['OverallCond']

data4['Total_Bathrooms'] = (data4['FullBath'] + (0.5 * data4['HalfBath']) +
                               data4['BsmtFullBath'] + (0.5 * data4['BsmtHalfBath']))

data4["HighQualSF"] = data4["1stFlrSF"] + data4["2ndFlrSF"]

# %%
data5 = data4.copy()

# %% [markdown]
# # Feature Transformations

# %% [markdown]
# ## Log Transform for Skewed Features

# %%
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False)
skew_df

# %%
for column in skew_df.query("Skewed == True")['Feature'].values:
    data5[column] = np.log1p(data5[column])

# %% [markdown]
# ## Cosine Transform for Cyclical Features

# %%
data4['MoSold'] = (-np.cos(0.5236 * data5['MoSold']))

# %%
data6 = data5.copy()

# %% [markdown]
# # Encode Categoricals

# %%
data6 = pd.get_dummies(data6)

# %%
data7 = data6.copy()

# %% [markdown]
# # Scaling

# %%
scaler = StandardScaler()
scaler.fit(data7)

data7 = pd.DataFrame(scaler.transform(data7), index=data7.index, columns=data7.columns)

# %%
data7

# %%
data8 = data7.copy()

# %% [markdown]
# # Target Transformation

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
sns.distplot(target, kde=True, fit=scipy.stats.norm)
plt.title("Without Log Transform")

plt.subplot(1, 2, 2)
sns.distplot(np.log(target), kde=True, fit=scipy.stats.norm)
plt.xlabel("Log SalePrice")
plt.title("With Log Transform")

plt.show()

# %%
log_target = np.log(target)

# %% [markdown]
# # Split Data

# %%
train_final = data8.loc[:train0.index.max(), :].copy()
test_final = data8.loc[train0.index.max() + 1:, :].reset_index(drop=True).copy()

# %%
train_final

# %%
test_final

# %% [markdown]
# # Model Selection

# %%
# _ = setup(data=pd.concat([train_final, log_target], axis=1), target='SalePrice')

# %%
# compare_models()

# %% [markdown]
# # Hyperparameter Optimization

# %%
# def br_objective(trial):
#     n_iter = trial.suggest_int('n_iter', 50, 600)
#     tol = trial.suggest_loguniform('tol', 1e-8, 10.0)
#     alpha_1 = trial.suggest_loguniform('alpha_1', 1e-8, 10.0)
#     alpha_2 = trial.suggest_loguniform('alpha_2', 1e-8, 10.0)
#     lambda_1 = trial.suggest_loguniform('lambda_1', 1e-8, 10.0)
#     lambda_2 = trial.suggest_loguniform('lambda_2', 1e-8, 10.0)
    
#     model = BayesianRidge(
#         n_iter=n_iter,
#         tol=tol,
#         alpha_1=alpha_1,
#         alpha_2=alpha_2,
#         lambda_1=lambda_1,
#         lambda_2=lambda_2
#     )
    
#     model.fit(train_final, log_target)
    
#     cv_scores = np.exp(np.sqrt(-cross_val_score(model, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))
    
#     return np.mean(cv_scores)

# %%
# study = optuna.create_study(direction='minimize')
# study.optimize(br_objective, n_trials=100)

# %%
# study.best_params

# %% [markdown]
# # Bagging Ensemble

# %%
catboost_params = {
    'iterations': 6000,
    'learning_rate': 0.005,
    'depth': 4,
    'l2_leaf_reg': 1,
    'eval_metric':'RMSE',
    'early_stopping_rounds': 200,
    'random_seed': 42
}

br_params = {
    'n_iter': 304,
    'tol': 0.16864712769300896,
    'alpha_1': 5.589616542154059e-07,
    'alpha_2': 9.799343618469923,
    'lambda_1': 1.7735725582463822,
    'lambda_2': 3.616928181181732e-06
}

lightgbm_params = {
    'num_leaves': 39,
    'max_depth': 2,
    'learning_rate': 0.13705339989856127,
    'n_estimators': 273
}

ridge_params = {
    'alpha': 631.1412445239156
}

# %%
models = {
    "catboost": CatBoostRegressor(**catboost_params, verbose=0),
    "br": BayesianRidge(**br_params),
    "lightgbm": LGBMRegressor(**lightgbm_params),
    "ridge": Ridge(**ridge_params),
    "omp": OrthogonalMatchingPursuit()
}

# %%
for name, model in models.items():
    model.fit(train_final, log_target)
    print(name + " trained.")

# %% [markdown]
# # Evaluate

# %%
results = {}

kf = KFold(n_splits=10)

for name, model in models.items():
    result = np.exp(np.sqrt(-cross_val_score(model, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))
    results[name] = result

# %%
results

# %%
for name, result in results.items():
    print("----------\n" + name)
    print(np.mean(result))
    print(np.std(result))

# %% [markdown]
# # Combine Predictions

# %%
final_predictions = (
    0.4 * np.exp(models['catboost'].predict(test_final)) +
    0.2 * np.exp(models['br'].predict(test_final)) +
    0.2 * np.exp(models['lightgbm'].predict(test_final)) +
    0.1 * np.exp(models['ridge'].predict(test_final)) +
    0.1 * np.exp(models['omp'].predict(test_final))
)

# %%
final_predictions

# %% [markdown]
# # Make Submission

# %%
submission = pd.concat([test_ids, pd.Series(final_predictions, name='SalePrice')], axis=1)
submission

# %%
submission.to_csv('./submission.csv', index=False, header=True)

# %% [markdown]
# # Livestream Included!
#
# ***
#
# This notebook was created during a YouTube live session.
# For an in-depth guide, check it out here!
# https://youtu.be/zwYHloLXH0c
